# %%
import math
import datetime
import my_module
import my_modules.prime_module
import my_modules.averages_module
import my_modules.palyndrome_module

# %%
print(math.sqrt(5), math.sqrt(16))
date = datetime.datetime.now()
print(date)
# Out:
# 2.23606797749979 4.0
# 2025-10-17 11:47:33.115483

# %%
for i in range(2, 100, 11):
    print(i, my_module.is_prime(i))
# Out:
# 2 False
# 13 True
# 24 False
# 35 False
# 46 False
# 57 False
# 68 False
# 79 True
# 90 False

# %%
for i in range(2, 100, 11):
    print(i, my_modules.prime_module.is_prime(i))
# Out:
# 2 False
# 13 True
# 24 False
# 35 False
# 46 False
# 57 False
# 68 False
# 79 True
# 90 False

# %%
a = '1234554321'
b = 'dcffcdf'
print(my_modules.palyndrome_module.is_palyndrome(a))
print(my_modules.palyndrome_module.is_palyndrome(b))
# Out:
# True
# False

# %%
nums = [1, 2, 3, 4, 5]
print(my_modules.averages_module.average_ariphmetic(nums))
print(my_modules.averages_module.average_geometric(nums))
print(my_modules.averages_module.average_harmonic(nums))
print(my_modules.averages_module.average_exponentional(nums, 2))
print(my_modules.averages_module.average_exponentional(nums, 3))
# Out:
# 3.0
# 2.605171084697352
# 2.18978102189781
# 3.3166247903554
# 3.5568933044900626
